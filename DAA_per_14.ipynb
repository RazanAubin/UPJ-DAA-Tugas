# %%
import networkx as nx
import matplotlib as plt

vertices = range(0,10)
edges = [(7,2),(2,3),(7,4),(4,5),(7,3),(7,5),(1,6),(1,7),(2,8),(2,9)]
node_f =[1,4,3,8,9]
node_nf =[2,5,6,7]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G, pos, nodelist=[1,4,3,8,9], node_color = 'g', node_size = 1300)
nx.draw_networkx_nodes(G, pos, nodelist=[2,5,6,7], node_color = 'r', node_size = 1300)
nx.draw_networkx_edges(G, pos, edges, width = 3, alpha = 0.5, edge_color = 'b')
labels = {}
labels [1] = r'1 NF'
labels [2] = r'2 F'
labels [3] = r'3 NF'
labels [4] = r'4 NF'
labels [5] = r'5 F'
labels [6] = r'6 F'
labels [7] = r'7 F'
labels [8] = r'8 NF'
labels [9] = r'9 NF'

nx.draw_networkx_labels(G, pos, labels, font_size = 10)
# Out:
# {1: Text(0.26876673959179787, 0.1251671639627436, '1 NF'),
#  2: Text(-0.3576827887802075, -0.01647005411422312, '2 F'),
#  3: Text(-0.16854741551584104, -0.0296742679798436, '3 NF'),
#  4: Text(-0.11432288685083836, 0.3955550898282844, '4 NF'),
#  5: Text(0.03340739635681223, 0.38223237020567735, '5 F'),
#  6: Text(0.5197669298484696, 0.12209957444024035, '6 F'),
#  7: Text(-0.05538827928232432, 0.15427901238885366, '7 F'),
#  8: Text(-0.5104853132852945, -0.23066620511043767, '8 NF'),
#  9: Text(-0.6155143820825747, 0.02451174778047905, '9 NF')}

# %%
nx.draw_networkx_nodes(G,pos,nodelist=[1,4,3,8,9],label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=[2,5,6,7],label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels= {}
labels[1]= r'1 NF'
labels[2]= r'2 F'
labels[3]= r'3 NF'
labels[4]= r'4 NF'
labels[5]= r'5 F'
labels[6]= r'6 F'
labels[7]= r'7 F'
labels[8]= r'8 NF'
labels[9]= r'9 NF'

labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos

dos_values ={node : calculate_dos(node) for node in G.nodes()}

# %%
vertices = range(0,11)
edges = [ (1,2),
          (1,7),
          (2,3),
          (2,6),
          (3,4),
          (3,6),
          (6,5),
          (7,6),
          (7,8),
          (7,9),
          (7,10),
          (8,9),
          ]
node_f =[1,7,10,4,5]
node_nf =[2,3,6,8,9]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels={}
labels[1]= r'1 F'
labels[2]= r'2 NF'
labels[3]= r'3 NF'
labels[4]= r'4 F'
labels[5]= r'5 F'
labels[6]= r'6 NF'
labels[7]= r'7 F'
labels[8]= r'8 NF'
labels[9]= r'9 NF'
labels[10]= r'10 F'

def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos
dos_values ={node : calculate_dos(node) for node in G.nodes()}
labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {0: Text(0.9999999999999999, 0.3604637947992878, '0 (0)'),
#  1: Text(-0.04628523209146535, 0.07628723045963619, '1 (2)'),
#  2: Text(0.06664877081324813, -0.05253667237127267, '2 (3)'),
#  3: Text(0.13947422758189912, -0.19011902329625793, '3 (3)'),
#  4: Text(0.28992318402534756, -0.2971425559424778, '4 (1)'),
#  5: Text(-0.12015025062498778, -0.29859463868464026, '5 (1)'),
#  6: Text(-0.058382126247629895, -0.12274949236600517, '6 (4)'),
#  7: Text(-0.22457643837592173, 0.07231541077305721, '7 (5)'),
#  8: Text(-0.39545513722783837, 0.1458219795358259, '8 (2)'),
#  9: Text(-0.40437282093744237, 0.04295441470825322, '9 (2)'),
#  10: Text(-0.2468241769152093, 0.263299552384593, '10 (1)')}

# %%
vertices = range(0,13)
edges = [ (1,2),
          (1,3),
          (2,3),
          (2,12),
          (3,4),
          (4,6),
          (4,5),
          (4,7),
          (7,8),
          (5,8),
          (8,9),
          (6,9),
          (3,11),
          (3,10),
          (12,11),
          (12,13),
          ]
node_f =[1,2,3,11,10,12]
node_nf =[13,4,5,6,7,8,9]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels={}
labels[1]= r'1 F'
labels[2]= r'2 F'
labels[3]= r'3 F'
labels[4]= r'4 NF'
labels[5]= r'5 NF'
labels[6]= r'6 NF'
labels[7]= r'7 NF'
labels[8]= r'8 NF'
labels[9]= r'9 NF'
labels[10]= r'10 F'
labels[11]= r'11 F'
labels[12]= r'12 F'
labels[13]= r'13 NF'

def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos

dos_values ={node : calculate_dos(node) for node in G.nodes()}
labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {0: Text(-0.9999284661398805, -1.0, '0 (0)'),
#  1: Text(0.3547834075937829, 0.044244768052738595, '1 (2)'),
#  2: Text(0.4317247459344741, 0.1703698473686861, '2 (3)'),
#  3: Text(0.19683825671763722, 0.14627457892051515, '3 (5)'),
#  4: Text(-0.1099507955145113, -0.019704487633672635, '4 (4)'),
#  5: Text(-0.33586130535442227, 0.026476485278966518, '5 (2)'),
#  6: Text(-0.23129302635390148, -0.24078374461511068, '6 (2)'),
#  7: Text(-0.28949428198083454, -0.0856308999194306, '7 (2)'),
#  8: Text(-0.4504499430738566, -0.12502867073522891, '8 (3)'),
#  9: Text(-0.42118211433062036, -0.3009161018672432, '9 (2)'),
#  10: Text(0.11696293125986498, 0.33022954997321036, '10 (1)'),
#  11: Text(0.388478537637729, 0.3062313934948455, '11 (2)'),
#  12: Text(0.584905305579331, 0.3241170250861728, '12 (3)'),
#  13: Text(0.7644667480252081, 0.42412025659555136, '13 (1)')}
